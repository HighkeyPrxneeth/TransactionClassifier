# %%
import pandas as pd
from glob import glob

files = glob('data/places-*.zstd.parquet')
df = pd.concat([pd.read_parquet(f) for f in files], ignore_index=True)
df
# Out:
#                       fsq_place_id                       name   latitude  \
# 0         8894b756f5b84fa765f83e89  Restaurant El Estoril Inc        NaN
# 1         3dd1d5d59cfa47e25f71b8ac                 ايمكو جروب        NaN
# 2         e437348c479d45ebb6a03deb             P.Z.-92 d.o.o.        NaN
# 3         59f3252f3b830724bb40e087  Bow Truss Coffee Roasters        NaN
# 4         56f25460498ed878ee1d2fc5                Teknofix HQ        NaN
# ...                            ...                        ...        ...
# 10687249  4b6dc32cf964a520678d2ce3           Teddy's Red Hots  41.752815
# 10687250  4f91bda77beb818efa88456c             Baskin-Robbins  41.752815
# 10687251  4dc02f64f7b115b875dabcb5          Country financial  41.752874
# 10687252  4c77fc33df08a1cd3ad5d55d                     Subway  41.752874
# 10687253  fb75321c1bbb4f2ece600ca4      Demi's Altered Images  41.752874
#
#           longitude                    address          locality  \
# 0               NaN    100 Calle Mendez Vigo E          Mayagüez
# 1               NaN  المنطقة الصناعية بور سعيد  المنطقة الصناعية
# 2               NaN                Kijevska 48            Zagreb
# 3               NaN              190 S Lasalle           Chicago
# 4               NaN   Küçükyalı Aydınevler Mh.          İstanbul
# ...             ...                        ...               ...
# 10687249 -87.963162          737 Plainfield Rd            Darien
# 10687250 -87.963162          737 Plainfield Rd            Darien
# 10687251 -87.963138          737 Plainfield Rd            Darien
# 10687252 -87.963138          737 Plainfield Rd            Darien
# 10687253 -87.963138    737 Plainfield Rd Ste 3            Darien
#
#                     region postcode admin_region post_town  ...  \
# 0                       PR    00680         None      None  ...
# 1                 بور سعيد     None         None      None  ...
# 2                     None    10000         None      None  ...
# 3                       IL    60603         None      None  ...
# 4         Maltepe/İstanbul     None         None      None  ...
# ...                    ...      ...          ...       ...  ...
# 10687249                IL    60561         None      None  ...
# 10687250                IL    60561         None      None  ...
# 10687251                IL    60561         None      None  ...
# 10687252                IL    60561         None      None  ...
# 10687253                IL    60561         None      None  ...
#
#                                      email   facebook_id instagram  \
# 0                                     None           NaN      None
# 1                                     None           NaN      None
# 2                                     None           NaN      None
# 3                                     None           NaN      None
# 4                                     None           NaN      None
# ...                                    ...           ...       ...
# 10687249               darien-il@patch.com  1.129585e+14      None
# 10687250         support@baskinrobbins.com  2.056861e+14      None
# 10687251  david.hegji@countryfinancial.com           NaN      None
# 10687252                              None           NaN      None
# 10687253                              None           NaN      None
#
#                  twitter                                   fsq_category_ids  \
# 0                   None                         [4d4b7105d754a06374d81259]
# 1                   None                         [63be6904847c3692a84b9b58]
# 2                   None                         [4d4b7105d754a06375d81259]
# 3                   None                                               None
# 4         teknofixonline                                               None
# ...                  ...                                                ...
# 10687249            None                         [4bf58dd8d48988d16f941735]
# 10687250   baskinrobbins  [4bf58dd8d48988d1c9941735, 4bf58dd8d48988d16a9...
# 10687251            None                         [58daa1558bbb0b01f18ec1f1]
# 10687252          subway  [4bf58dd8d48988d1c5941735, 4bf58dd8d48988d16e9...
# 10687253            None                         [4bf58dd8d48988d110951735]
#
#                                         fsq_category_labels  \
# 0                        [Dining and Drinking > Restaurant]
# 1         [Business and Professional Services > Home Imp...
# 2                      [Business and Professional Services]
# 3                                                      None
# 4                                                      None
# ...                                                     ...
# 10687249  [Dining and Drinking > Restaurant > Hot Dog Jo...
# 10687250  [Dining and Drinking > Dessert Shop > Ice Crea...
# 10687251  [Business and Professional Services > Insuranc...
# 10687252  [Dining and Drinking > Restaurant > Sandwich S...
# 10687253  [Business and Professional Services > Health a...
#
#                                              placemaker_url unresolved_flags  \
# 0         https://foursquare.com/placemakers/review-plac...             None
# 1         https://foursquare.com/placemakers/review-plac...             None
# 2         https://foursquare.com/placemakers/review-plac...             None
# 3         https://foursquare.com/placemakers/review-plac...             None
# 4         https://foursquare.com/placemakers/review-plac...             None
# ...                                                     ...              ...
# 10687249  https://foursquare.com/placemakers/review-plac...             None
# 10687250  https://foursquare.com/placemakers/review-plac...             None
# 10687251  https://foursquare.com/placemakers/review-plac...             None
# 10687252  https://foursquare.com/placemakers/review-plac...             None
# 10687253  https://foursquare.com/placemakers/review-plac...             None
#
#                                                        geom  \
# 0                                                      None
# 1                                                      None
# 2                                                      None
# 3                                                      None
# 4                                                      None
# ...                                                     ...
# 10687249  b"\x00\x00\x00\x00\x01\xc0U\xfd\xa4t'p\x86@D\x...
# 10687250  b"\x00\x00\x00\x00\x01\xc0U\xfd\xa4t'p\x86@D\x...
# 10687251  b'\x00\x00\x00\x00\x01\xc0U\xfd\xa4\x0c\xbf%\x...
# 10687252  b'\x00\x00\x00\x00\x01\xc0U\xfd\xa4\x0c\xbf%\x...
# 10687253  b'\x00\x00\x00\x00\x01\xc0U\xfd\xa4\x0c\xbf%\x...
#
#                                                        bbox
# 0                                                      None
# 1                                                      None
# 2                                                      None
# 3                                                      None
# 4                                                      None
# ...                                                     ...
# 10687249  {'xmin': -87.96316245891111, 'ymin': 41.752814...
# 10687250  {'xmin': -87.96316245891111, 'ymin': 41.752814...
# 10687251  {'xmin': -87.96313780466781, 'ymin': 41.752874...
# 10687252  {'xmin': -87.96313780466781, 'ymin': 41.752874...
# 10687253  {'xmin': -87.96313780466781, 'ymin': 41.752874...
#
# [10687254 rows x 27 columns]
